# %%
import pandas as pd
import numpy as np

df = pd.read_csv('.\\Dataset\\dataset_all_1.csv')

df_download_media = df[(df.Tipo == "Download")]

df_download_media
# Out:
#        Unnamed: 0       Operatore  \
# 0               0  BritishTelecom
# 3               3  BritishTelecom
# 6               6            Eolo
# 9               9            Eolo
# 14             14         Fastweb
# ...           ...             ...
# 11649       11649             TIM
# 11652       11652             TIM
# 11655       11655         Tiscali
# 11658       11658            Wind
# 11661       11661            Wind
#
#                                                  Profilo  \
# 0               BTADSL7Mega,VipPremium,VipDuet,VipAssolo
# 3           VipClub7Mega,VipSmart7Mega,VipDuet,VipAssolo
# 6                                                    NaN
# 9                                                Formula
# 14                                      Superjet,Joy,Jet
# ...                                                  ...
# 11649                                       TIMSuperADSL
# 11652                                       TIMSuperMega
# 11655                                                NaN
# 11658  WindHomeADSL,3ADSL,AbsoluteADSL,AllInclusive,A...
# 11661  WindHomeADSL,3ADSL,AbsoluteADSL,AllInclusive,A...
#
#           Velocità (down/up) Territorio             Periodo      Tipo  \
# 0       \n7,0Mbps832.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 3         \n7,0Mbps1,0Mbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 6       \n7,0Mbps384.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 9       \n7,0Mbps512.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 14      \n10,0Mbps10,2Mbps\n   Piemonte  \nGen2014Giu2014\n  Download
# ...                      ...        ...                 ...       ...
# 11649    \n10,0Mbps1,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 11652    \n30,0Mbps3,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 11655  \n100,0Mbps20,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 11658   \n8,0Mbps512.0kbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 11661    \n10,0Mbps1,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
#
#           Media Dev. Std.       Min      Max  TP%  Misure  Anno
# 0       6,1Mbps      34,3   6,0Mbps  6,1Mbps  NaN   40340  2014
# 3       5,9Mbps      68,5   5,8Mbps  6,0Mbps  NaN   42096  2014
# 6       6,0Mbps    1059,8   4,0Mbps  6,8Mbps  NaN   37320  2014
# 9       6,7Mbps     386,9   6,1Mbps  6,9Mbps  NaN   28013  2014
# 14      9,4Mbps     163,9   9,4Mbps  9,4Mbps  NaN   38340  2014
# ...         ...       ...       ...      ...  ...     ...   ...
# 11649   9,8Mbps     616,7   9,8Mbps      NaN  NaN    2635  2022
# 11652  29,6Mbps       3,1  29,6Mbps      NaN  NaN    8127  2022
# 11655  66,1Mbps    3168,9  64,4Mbps      NaN  NaN    7200  2022
# 11658   6,9Mbps     333,8   6,9Mbps      NaN  NaN    8986  2022
# 11661   8,9Mbps       0,8   8,9Mbps      NaN  NaN    3556  2022
#
# [3604 rows x 14 columns]

# %%
import re
m = []
for i in range(0, len(df_download_media)):
    m.append(float(re.findall("[-+]?(?:\d*\,*\d+)", df_download_media.iloc[i].Media)[0].replace(',','.')))
df_download_media["media_f"] = m
df_download_media = df_download_media.drop(["Unnamed: 0","Profilo","Velocità (down/up)","Territorio","Periodo","Tipo","Media","Dev. Std.","Min","Max","TP%","Misure"],axis = 1)
df_download_media = df_download_media.groupby(["Operatore","Anno"]).mean().reset_index()
df_download_media
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1564\970307678.py in ?()
#       1 import re
#       2 m = []
#       3 for i in range(0, len(df_download_media)):
# ----> 4     m.append(float(re.findall("[-+]?(?:\d*\,*\d+)", df_download_media.iloc[i].Media)[0].replace(',','.')))
#       5 df_download_media["media_f"] = m
#       6 df_download_media = df_download_media.drop(["Unnamed: 0","Profilo","Velocità (down/up)","Territorio","Periodo","Tipo","Media","Dev. Std.","Min","Max","TP%","Misure"],axis = 1)
#       7 df_download_media = df_download_media.groupby(["Operatore","Anno"]).mean().reset_index()
#
# ~\bul_study\datavis\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Media'

# %%
import matplotlib.pyplot as plt
anni = np.sort(df_download_media.Anno.unique())
tim_velocita = []
for operatore in df_download_media.Operatore.unique():
    print(operatore)
    velocita = []
    for anno in anni:
        print(anno)
        media_anno = df_download_media[(df_download_media.Operatore == operatore) & (df_download_media.Anno == anno)].media_f.values
        if len(media_anno) == 0:
            velocita.append(np.nan)
        else:
            velocita.append(media_anno[0])
    print(velocita)
    print(anni)
    if(operatore == "TIM"):
        tim_velocita = velocita
    
    plt.plot(anni, velocita, 'k--')
plt.plot(anni, tim_velocita, 'r-')
# Out:
# Acantho
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# [9.274999999999999, 9.425, 9.15, 9.15, 9.4, 10.55, 9.8, 8.85, 9.025]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022]
# Aruba
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# [11.091666666666667, 11.333333333333334, 10.5, 12.625, 11.875, 11.450000000000001, nan, 13.299999999999999, 783.375]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022]
# Brennercom
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# [4.8, 4.8, 4.8, 5.1499999999999995, 5.074999999999999, 5.05, 5.05, 5.05, 4.699999999999999]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022]
# BritishTelecom
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# [5.7550724637681165, 5.982089552238806, 6.9173913043478255, 8.6734375, 9.202941176470588, 9.48923076923077, 10.535185185185185, 11.63695652173913, 36.7]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022]
# ColtTelecom
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
#