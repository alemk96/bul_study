# %%
#Geopandas installation
import sys
'geopandas' in sys.modules
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in e:\python\lib\site-packages (0.14.1)
# Requirement already satisfied: pandas>=1.4.0 in e:\python\lib\site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: packaging in e:\python\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely>=1.8.0 in e:\python\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyproj>=3.3.0 in e:\python\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: fiona>=1.8.21 in e:\python\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: attrs>=19.2.0 in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (21.4.0)
# Requirement already satisfied: certifi in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (2022.9.14)
# Requirement already satisfied: click~=8.0 in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: importlib-metadata in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (4.11.3)
# Requirement already satisfied: six in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in e:\python\lib\site-packages (from fiona>=1.8.21->geopandas) (63.4.1)
# Requirement already satisfied: pytz>=2020.1 in e:\python\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\python\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in e:\python\lib\site-packages (from pandas>=1.4.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in e:\python\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in e:\python\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in e:\python\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.8.0)

# %%
#we import the data of both Italy, Covid and new_regions
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

italy = gpd.read_file('reg2011_g.shp')
new_regions = pd.read_csv('reg2011_g.csv')

# %%
#We substitute the right column containing regions
italy['NOME_REG'] = new_regions['NOME_REG']
italy.head(20)
# Out:
#     COD_REG               NOME_REG    SHAPE_Leng    SHAPE_Area  \
# 0         1               Piemonte  1.236869e+06  2.539410e+10
# 1         2                  Aosta  3.111651e+05  3.259041e+09
# 2         3              Lombardia  1.411265e+06  2.386270e+10
# 3         4               Trentino  8.005341e+05  1.360802e+10
# 4         5                 Veneto  1.057856e+06  1.840550e+10
# 5         6  Friuli-Venezia Giulia  6.674897e+05  7.864294e+09
# 6         7                Liguria  8.342245e+05  5.415465e+09
# 7         8         Emilia-Romagna  1.164723e+06  2.245147e+10
# 8         9                Toscana  1.316658e+06  2.298443e+10
# 9        10                 Umbria  6.203152e+05  8.464008e+09
# 10       11                 Marche  6.292090e+05  9.401178e+09
# 11       12                  Lazio  1.055355e+06  1.722762e+10
# 12       13                Abruzzo  6.145137e+05  1.082910e+10
# 13       14                 Molise  4.338747e+05  4.461149e+09
# 14       15               Campania  8.923791e+05  1.366399e+10
# 15       16                 Puglia  1.176243e+06  1.953708e+10
# 16       17             Basilicata  6.142192e+05  1.007326e+10
# 17       18               Calabria  8.381944e+05  1.521668e+10
# 18       19                Sicilia  1.339974e+06  2.582478e+10
# 19       20               Sardegna  1.460657e+06  2.409417e+10
#
#                                              geometry
# 0   POLYGON ((457832.312 5145701.000, 458745.249 5...
# 1   POLYGON ((390734.999 5091965.001, 390830.999 5...
# 2   MULTIPOLYGON (((595736.187 5163715.001, 596126...
# 3   POLYGON ((743386.080 5219948.900, 743472.190 5...
# 4   POLYGON ((768209.001 5175597.001, 768220.251 5...
# 5   MULTIPOLYGON (((852211.994 5080672.916, 852270...
# 6   MULTIPOLYGON (((400403.625 4851436.938, 400257...
# 7   MULTIPOLYGON (((760714.748 4937319.399, 760723...
# 8   MULTIPOLYGON (((593650.250 4867988.000, 593553...
# 9   MULTIPOLYGON (((771407.451 4833282.073, 771402...
# 10  MULTIPOLYGON (((863162.283 4840139.829, 863195...
# 11  MULTIPOLYGON (((802704.568 4594643.932, 802540...
# 12  POLYGON ((901880.250 4760558.000, 901910.750 4...
# 13  POLYGON ((984090.000 4670910.250, 985154.250 4...
# 14  MULTIPOLYGON (((925294.173 4528798.912, 925329...
# 15  MULTIPOLYGON (((1141891.750 4588535.750, 11418...
# 16  MULTIPOLYGON (((1074503.688 4446135.938, 10744...
# 17  MULTIPOLYGON (((1084888.411 4414364.607, 10848...
# 18  MULTIPOLYGON (((803299.052 4188096.575, 803275...
# 19  MULTIPOLYGON (((432678.313 4492760.313, 432811...

# %%
f_path = "C:/Users/alex/Downloads/dataset_all_2.csv"
df =  pd.read_csv(f_path)
df.Territorio.unique()
# Out:
# array(['Piemonte', "Valled'Aosta", 'Lombardia', 'Trentino-AltoAdige',
#        'Veneto', 'Friuli-VeneziaGiulia', 'Liguria', 'Emilia-Romagna',
#        'Toscana', 'Umbria', 'Marche', 'Lazio', 'Abruzzo', 'Molise',
#        'Campania', 'Puglia', 'Basilicata', 'Sicilia', 'Sardegna'],
#       dtype=object)

# %%
df.Territorio = df.Territorio.replace(["Valled'Aosta"], 'Aosta' )
df.Territorio = df.Territorio.replace(["Trentino-AltoAdige"], 'Trentino' )
df.Territorio = df.Territorio.replace(["Friuli-VeneziaGiulia"], 'Friuli-Venezia Giulia' )
df_download_media = df[df.Tipo == "Download"]

import re
m = []
for i in range(0, len(df_download_media)):
    m.append(float(re.findall("[-+]?(?:\d*\,*\d+)", df_download_media.iloc[i].Media)[0].replace(',','.')))

df_download_media["media_f"] = m
df_download_media.groupby(["Territorio","Anno"]).sum().reset_index()['Misure']

df_download_media_somma = df_download_media.groupby(["Territorio","Anno"]).sum().reset_index().drop(['Unnamed: 0','media_f'],axis = 1)

df_download_media_somma['misure_totali_anno'] = df_download_media_somma['Misure']
df_download_media_somma = df_download_media_somma.drop('Misure',axis = 1)
df_download_media_somma
# Out:
# C:\Users\alex\AppData\Local\Temp\ipykernel_19832\2792175464.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_download_media["media_f"] = m
#     Territorio  Anno  misure_totali_anno
# 0      Abruzzo  2014              936791
# 1      Abruzzo  2015              838078
# 2      Abruzzo  2016              186903
# 3      Abruzzo  2017              132121
# 4      Abruzzo  2018              173836
# ..         ...   ...                 ...
# 160     Veneto  2018              194459
# 161     Veneto  2019              161566
# 162     Veneto  2020               88449
# 163     Veneto  2021               49269
# 164     Veneto  2022               77439
#
# [165 rows x 3 columns]

# %%
df_download_media = df_download_media.merge(df_download_media_somma, on=['Territorio','Anno'], how='left').reset_index()
df_download_media['media_f'] = df_download_media['media_f'] * df_download_media['Misure'] / df_download_media['misure_totali_anno']
df_download_media
# Out:
#       index  Unnamed: 0       Operatore  \
# 0         0           0  BritishTelecom
# 1         1           3  BritishTelecom
# 2         2           6            Eolo
# 3         3           9            Eolo
# 4         4          14         Fastweb
# ...     ...         ...             ...
# 3599   3599       11649             TIM
# 3600   3600       11652             TIM
# 3601   3601       11655         Tiscali
# 3602   3602       11658            Wind
# 3603   3603       11661            Wind
#
#                                                 Profilo  \
# 0              BTADSL7Mega,VipPremium,VipDuet,VipAssolo
# 1          VipClub7Mega,VipSmart7Mega,VipDuet,VipAssolo
# 2                                                  None
# 3                                               Formula
# 4                                      Superjet,Joy,Jet
# ...                                                 ...
# 3599                                       TIMSuperADSL
# 3600                                       TIMSuperMega
# 3601                                               None
# 3602  WindHomeADSL,3ADSL,AbsoluteADSL,AllInclusive,A...
# 3603  WindHomeADSL,3ADSL,AbsoluteADSL,AllInclusive,A...
#
#          Velocità (down/up) Territorio             Periodo      Tipo  \
# 0      \n7,0Mbps832.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 1        \n7,0Mbps1,0Mbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 2      \n7,0Mbps384.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 3      \n7,0Mbps512.0kbps\n   Piemonte  \nGen2014Giu2014\n  Download
# 4      \n10,0Mbps10,2Mbps\n   Piemonte  \nGen2014Giu2014\n  Download
# ...                     ...        ...                 ...       ...
# 3599    \n10,0Mbps1,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 3600    \n30,0Mbps3,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 3601  \n100,0Mbps20,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 3602   \n8,0Mbps512.0kbps\n   Sardegna  \nLug2022Dic2022\n  Download
# 3603    \n10,0Mbps1,0Mbps\n   Sardegna  \nLug2022Dic2022\n  Download
#
#          Media Dev. Std.       Min      Max  TP%  Misure  Anno   media_f  \
# 0      6,1Mbps      34,3   6,0Mbps  6,1Mbps  NaN   40340  2014  0.272739
# 1      5,9Mbps      68,5   5,8Mbps  6,0Mbps  NaN   42096  2014  0.275280
# 2      6,0Mbps    1059,8   4,0Mbps  6,8Mbps  NaN   37320  2014  0.248184
# 3      6,7Mbps     386,9   6,1Mbps  6,9Mbps  NaN   28013  2014  0.208025
# 4      9,4Mbps     163,9   9,4Mbps  9,4Mbps  NaN   38340  2014  0.399449
# ...        ...       ...       ...      ...  ...     ...   ...       ...
# 3599   9,8Mbps     616,7   9,8Mbps      NaN  NaN    2635  2022  0.169184
# 3600  29,6Mbps       3,1  29,6Mbps      NaN  NaN    8127  2022  1.576063
# 3601  66,1Mbps    3168,9  64,4Mbps      NaN  NaN    7200  2022  3.118068
# 3602   6,9Mbps     333,8   6,9Mbps      NaN  NaN    8986  2022  0.406225
# 3603   8,9Mbps       0,8   8,9Mbps      NaN  NaN    3556  2022  0.207350
#
#       misure_totali_anno
# 0                 902233
# 1                 902233
# 2                 902233
# 3                 902233
# 4                 902233
# ...                  ...
# 3599              152633
# 3600              152633
# 3601              152633
# 3602              152633
# 3603              152633
#
# [3604 rows x 17 columns]

# %%
df_download_media = df_download_media.drop(["Unnamed: 0","Profilo","Velocità (down/up)","Operatore","Periodo","Tipo","Media","Dev. Std.","Min","Max","TP%","Misure"],axis = 1)

df_download_media = df_download_media.groupby(["Territorio","Anno"]).sum().reset_index()
df_download_media['NOME_REG'] = df_download_media['Territorio']
df_download_media = df_download_media.drop(['index','misure_totali_anno'],axis = 1)
df_download_media
# Out:
#     Territorio  Anno    media_f NOME_REG
# 0      Abruzzo  2014   7.234012  Abruzzo
# 1      Abruzzo  2015   7.443062  Abruzzo
# 2      Abruzzo  2016   9.124112  Abruzzo
# 3      Abruzzo  2017   9.115773  Abruzzo
# 4      Abruzzo  2018   8.784971  Abruzzo
# ..         ...   ...        ...      ...
# 160     Veneto  2018  10.511426   Veneto
# 161     Veneto  2019  12.589614   Veneto
# 162     Veneto  2020  20.475254   Veneto
# 163     Veneto  2021  27.843985   Veneto
# 164     Veneto  2022  36.057401   Veneto
#
# [165 rows x 4 columns]

# %%
#merging the two datasets
merge = italy.merge(df_download_media[df_download_media["Anno"] == 2021], on='NOME_REG', how='left')

merge.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COD_REG     20 non-null     int64
#  1   NOME_REG    20 non-null     object
#  2   SHAPE_Leng  20 non-null     float64
#  3   SHAPE_Area  20 non-null     float64
#  4   geometry    20 non-null     geometry
#  5   Territorio  19 non-null     object
#  6   Anno        19 non-null     float64
#  7   media_f     19 non-null     float64
# dtypes: float64(4), geometry(1), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
anni = df_download_media["Anno"].unique()
for anno in anni:
    print(anno)
    merge = italy.merge(df_download_media[df_download_media["Anno"] == anno], on='NOME_REG', how='left')

    fig, ax = plt.subplots(1, figsize=(15, 15))
    ax.set_facecolor("#F2F2F2")
    col = 'media_f'
    merge.loc[20] = [0,'Artificial_min',0,0,None,None,0,0]
    merge.loc[20] = [0,'Artificial_max',0,0,None,None,0,400]
    ax.set_title(col, fontdict={'fontsize':'25', 'fontweight':'3'}, color='Red', fontfamily='monospace')
    my_plot = merge.plot(ax=ax,
               column=col,
               cmap='BuPu',
               label='ciao',
               legend=True,
               categorical=False)
    #colore diverso per dati mancanti calabria
    merge.loc[17,'media_f'] = 100
    merge.loc['Calabria','media_f'] = 100
    my_plot = merge[merge.NOME_REG == 'Calabria'].plot(
        ax=ax,
        column=col,
        cmap='PuOr',
        label='ciao',
        legend=False,
        categorical=True
    )
    fig = my_plot.get_figure()
    fig.savefig("italia_" + str(anno) +".png")
    plt.show()
    plt.clf()
# Out:
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
